# %% [markdown]
# # Netflix Dataset Project

# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\Admin\Downloads\8. Netflix Dataset.csv")

# %% [markdown]
# # Dataset information

# %%
data.shape                                           #to show number of rows and columns
# Out:
# (7787, 12)

# %%
data.head()                                            #to show top 5 elements from the dataset
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.size                                  #total size of the dataset
# Out:
# 93444

# %%
data.columns                        #it shows all the column names
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.dtypes                    #to show data type of each column
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
 data.info()                                          #to give some details about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# Step 1: To remove duplicates if any present in dataset

# %%
data.shape
# Out:
# (7789, 11)

# %%
data[data.duplicated()]                             #to find whether any duplicates are present
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace = True)         #to remove the duplicates from the dataset permanantly

# %%
data.shape
# Out:
# (7787, 11)

# %% [markdown]
# Step 2: To check if there is any null data in the dataset

# %%
data.isnull()                          #checking for null values
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
data.isnull().sum()                     #to show the number of null values present
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())                   #showing null values by a heatmap
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Finding a particular element from the dataset using isin function

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data[data['Title'].isin(['House of Cards'])]          #Finding a particular element using title of the show
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# # Task: Show using a bargraph In which year highest number of tv shows and movies were relaeased

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data['Date_time'] = pd.to_datetime(data['Release_Date'])      #creating new column and coverting relase date column to datetime format to save in this column

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_time       datetime64[ns]
# dtype: object

# %%
data['Date_time'].dt.year.value_counts()      #it shows all the occurunce counts of the tvshows and movies relaesed in every year
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_time, dtype: int64

# %%
data['Date_time'].dt.year.value_counts().plot(kind='bar',title='No. of TV shows/Movies Released vs Year') #Displays the information using a bar graph
# Out:
# <AxesSubplot:title={'center':'No. of TV shows/Movies Released vs Year'}>

# %%
data.head(4)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# ...

# %% [markdown]
# # Task: To show count of two categories that are Tv shows and movies

# %%
data.groupby('Category').Category.count()     #We use groupby function to categorize the data into its subtypes
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(data['Category'])     #Using bar graph showing the number of movies and Tv shows
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# # Task: Show all the movies released in year 2018

# %%
data['Year'] = data['Date_time'].dt.year         #Creating new column which has relase year

# %%
data.head(4)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# ...

# %%
 data[(data['Category'] == 'Movie') & (data['Year'] == 2018)]
# Out:
#      Show_Id Category                     Title          Director  \
# 2         s3    Movie                     23:59      Gilbert Chan
# 17       s18    Movie                    22-Jul   Paul Greengrass
# 19       s20    Movie                       '89               NaN
# 20       s21    Movie      ​​Kuch Bheege Alfaaz              Onir
# 21       s22    Movie              ​Goli Soda 2      Vijay Milton
# ...      ...      ...                       ...               ...
# 7765   s7764    Movie                     Zenda    Avadhoot Gupte
# 7770   s7769    Movie  Zindagi Kitni Haseen Hay     Anjum Shahzad
# 7773   s7772    Movie                      Zion        Floyd Russ
# 7778   s7777    Movie                  Zokkomon  Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo      Shlok Sharma
#
#                                                    Cast  \
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 17    Anders Danielsen Lie, Jon Øigarden, Jonas Stra...
# ...

# %% [markdown]
# # Task: Showing only Titles of TV shows relased in India

# %%
data.head(4)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# ...

# %%
data[(data['Category'] == 'TV Show') & (data['Country'] == 'India')] ['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# # Task: Show the top 10 directors who gave highest number of releases

# %%
data.head(4)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# ...

# %%
data['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Martin Scorsese           12
# Youssef Chahine           12
# Steven Spielberg          10
# David Dhawan               9
# Ryan Polito                8
# Name: Director, dtype: int64

# %%
data['Type'].value_counts().head(10)
# Out:
# Documentaries                                       334
# Stand-Up Comedy                                     321
# Dramas, International Movies                        320
# Comedies, Dramas, International Movies              243
# Dramas, Independent Movies, International Movies    215
# Kids' TV                                            205
# Children & Family Movies                            177
# Documentaries, International Movies                 172
# Children & Family Movies, Comedies                  169
# Comedies, International Movies                      161
# Name: Type, dtype: int64

# %% [markdown]
# # Task: Show all the movies of type Family movies or movies from Brazil

# %%
data.head(4)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# ...

# %%
data[(data['Category'] == 'Movie') & (data['Type'] == 'Children & Family Movies') | (data['Country'] == 'Brazil')]  #Using or function
# Out:
#      Show_Id Category                                              Title  \
# 0         s1  TV Show                                                 3%
# 147     s148    Movie            A Babysitter's Guide to Monster Hunting
# 177     s178    Movie                    A Go! Go! Cory Carson Christmas
# 178     s179    Movie                    A Go! Go! Cory Carson Halloween
# 179     s180    Movie                  A Go! Go! Cory Carson Summer Camp
# ...      ...      ...                                                ...
# 7629   s7628    Movie  Willy and the Guardians of the Lake: Tales fro...
# 7645   s7644    Movie                                Wish Upon a Unicorn
# 7718   s7717    Movie                               Yoko and His Friends
# 7725   s7724    Movie                                       You Can Tutu
# 7758   s7757  TV Show                                                 Z4
#
#                      Director  \
# 0                         NaN
# ...

# %% [markdown]
# # Removing all the null values in the dataset

# %% [markdown]
# For that we have to create a new data frame and store the dataset with non null values in that frame

# %%
data_new = data.dropna()

# %%
data_new.shape           #new data frame shape without null values
# Out:
# (4809, 13)

# %%
data_new.head(4)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating Duration  \
# 1  December 23, 2016  TV-MA   93 min
# 2  December 20, 2018      R   78 min
# 3  November 16, 2017  PG-13   80 min
# 4    January 1, 2020  PG-13  123 min
#
#                                                 Type  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# ...

# %% [markdown]
# # Task : Show all the movies with Tom cruise in them

# %%
data_new[data_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description  Date_time    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# # Showing all the unique ratings from the dataset

# %% [markdown]
# using nunique() function we can see  number of unique ratings used by netflix

# %%
data['Rating'].nunique()
# Out:
# 14

# %%
data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# # Show TV-PG rated movies in Canada

# %%
data[(data['Category'] == 'Movie') & (data['Rating'] == 'TV-PG') & (data['Country'] == 'Canada')]
# Out:
#      Show_Id Category                                              Title  \
# 101     s102    Movie                                  3 Seconds Divorce
# 1119   s1120    Movie               Bruno and Boots: Go Jump in the Pool
# 1120   s1121    Movie                    Bruno and Boots: The Wizzle War
# 1121   s1122    Movie  Bruno and Boots: This Can't Be Happening at Ma...
# 1248   s1249    Movie           Catwalk: Tales from the Cat Show Circuit
# 1370   s1371    Movie                            Christmas with a Prince
# 1371   s1372    Movie                              Christmas With A View
# 1665   s1666    Movie                                         Dear Santa
# 2552   s2553    Movie                                        Gun Runners
# 3044   s3045    Movie               Invisible Essence: The Little Prince
# 4013   s4014    Movie                                    Meditation Park
# 4304   s4305    Movie               My Babysitter's a Vampire: The Movie
# ...

# %%
data[(data['Category'] == 'Movie') & (data['Rating'] == 'TV-PG') & (data['Country'] == 'Canada')].shape
# Out:
# (14, 13)

# %% [markdown]
# # Showing all the Movies with R rating after year 2018

# %%
data[(data['Category'] == 'Movie') & (data['Rating'] == 'R') & (data['Year'] > 2018)]
# Out:
#      Show_Id Category               Title                       Director  \
# 7         s8    Movie                 187                 Kevin Reynolds
# 14       s15    Movie                3022                     John Suits
# 65       s66    Movie             13 Sins                   Daniel Stamm
# 68       s69    Movie           14 Blades                     Daniel Lee
# 83       s84    Movie  20th Century Women                     Mike Mills
# ...      ...      ...                 ...                            ...
# 7659   s7658    Movie           Woodshock  Kate Mulleavy, Laura Mulleavy
# 7712   s7711    Movie       Yes, God, Yes                    Karen Maine
# 7738   s7737    Movie         Young Adult                  Jason Reitman
# 7776   s7775    Movie              Zodiac                  David Fincher
# 7780   s7779    Movie          Zombieland                Ruben Fleischer
#
#                                                    Cast  \
# ...

# %% [markdown]
# # Task: Show the longest duration movie

# %%
data.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description  Date_time    Year
# ...

# %%
data.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data.Duration.dtypes
# Out:
# dtype('O')

# %%
data[['Minutes','Unit']] = data['Duration'].str.split(' ' , expand = True)

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description  Date_time    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
data['Minutes'].max()
# Out:
# '99'

# %% [markdown]
# # Show the country which has highest number of TV shows

# %%
data_tvshow = data[(data['Category'] == 'TV Show') ]

# %%
data_tvshow.head(4)
# Out:
#    Show_Id Category Title              Director  \
# 0       s1  TV Show    3%                   NaN
# 5       s6  TV Show    46           Serdar Akar
# 11     s12  TV Show  1983                   NaN
# 12     s13  TV Show  1994  Diego Enrique Osorno
#
#                                                  Cast                Country  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...                 Brazil
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...                 Turkey
# 11  Robert Więckiewicz, Maciej Musiał, Michalina O...  Poland, United States
# 12                                                NaN                 Mexico
#
#          Release_Date Rating   Duration  \
# 0     August 14, 2020  TV-MA  4 Seasons
# 5        July 1, 2017  TV-MA   1 Season
# 11  November 30, 2018  TV-MA   1 Season
# 12       May 17, 2019  TV-MA   1 Season
#
#                                                  Type  \
# 0   International TV Shows, TV Dramas, TV Sci-Fi &...
# ...

# %%
data_tvshow.Country.value_counts()
# Out:
# United States                              705
# United Kingdom                             204
# Japan                                      157
# South Korea                                147
# India                                       71
#                                           ...
# France, United Kingdom                       1
# Australia, Canada                            1
# United States, Hungary, Ireland, Canada      1
# Germany, United States, Italy                1
# United Kingdom, France, Germany, Spain       1
# Name: Country, Length: 183, dtype: int64

# %%
sns.countplot(x=data_tvshow['Country'],data=data_tvshow.Country.value_counts())
sns.set(rc={'figure.figsize':(8,20)})

# %%
data_tvshow.Country.value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %% [markdown]
# # Sorting the Data set

# %%
data_new.sort_values(by = 'Country').head(4) #Sorting by Countries
# Out:
#      Show_Id Category                     Title                Director  \
# 2148   s2149    Movie  Fernando Sanjiao: Hombre  Raúl Campos, Jan Suter
# 3988   s3989    Movie                     Mater        Pablo D'Alo Abba
# 2884   s2885    Movie               Hypersomnia          Gabriel Grieco
# 4746   s4747    Movie         Palermo Hollywood           Eduardo Pinto
#
#                                                    Cast    Country  \
# 2148                                   Fernando Sanjiao  Argentina
# 3988  Lautaro Perotti, Tamara Kiper, Inda Lavalle, M...  Argentina
# 2884  Yamila Saud, Gerardo Romano, Jimena Barón, Van...  Argentina
# 4746  Brian Maya, Matías Desiderio, Manuela Pal, Azu...  Argentina
#
#          Release_Date Rating Duration  \
# 2148     May 25, 2018  TV-MA   63 min
# 3988   August 1, 2018  TV-MA   80 min
# 2884     June 8, 2017  TV-MA   84 min
# 4746  October 8, 2020  TV-MA  106 min
#
#                                                   Type  \
# ...

# %%
data_new.sort_values(by = 'Year' , ascending = False).head(4)  #Sorting by Years Released in Descending order
# Out:
#      Show_Id Category               Title                         Director  \
# 2269   s2270    Movie          Fred Claus                     David Dobkin
# 2349   s2350    Movie           Gangaajal                      Prakash Jha
# 6248   s6248    Movie  The Creative Brain  Jennifer Beamish, Toby Trackman
# 1673   s1674    Movie         Death of Me              Darren Lynn Bousman
#
#                                                    Cast  \
# 2269  Vince Vaughn, Paul Giamatti, John Michael Higg...
# 2349  Ajay Devgn, Gracy Singh, Mohan Agashe, Mohan J...
# 6248                                     David Eagleman
# 1673  Maggie Q, Luke Hemsworth, Alex Essoe, Ingkarat...
#
#                       Country      Release_Date Rating Duration  \
# 2269            United States   January 1, 2021     PG  115 min
# 2349                    India   January 8, 2021  TV-MA  148 min
# 6248            United States   January 1, 2021  TV-14   53 min
# ...

# %% [markdown]
# # Show all Kids TV show and Drama Movies

# %%
data[(data['Category'] == 'TV Show') & (data['Type'] == "Kids' TV") | (data['Category'] == 'Movie') & (data['Type'] == 'Drama')]
# Out:
#      Show_Id Category              Title             Director  \
# 111     s112  TV Show            44 Cats                  NaN
# 276     s277  TV Show       Abby Hatcher          Kyran Kelly
# 434     s435  TV Show        Alphablocks                  NaN
# 598     s599  TV Show  Ask the StoryBots                  NaN
# 706     s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
# ...      ...      ...                ...                  ...
# 7668   s7667  TV Show      World of Winx       Iginio Straffi
# 7717   s7716  TV Show               Yoko                  NaN
# 7719   s7718  TV Show                YOM                  NaN
# 7758   s7757  TV Show                 Z4                  NaN
# 7761   s7760  TV Show          Zak Storm                  NaN
#
#                                                    Cast  \
# 111   Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 276   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# ...

# %%
 data_new.head(5)                        #dataset with no null values
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...
